# %% [markdown]
# ### Twitter API
#
# Sources
# Twitter API: https://developer.twitter.com/en/docs/api-reference-index
#
# Tweepy document: http://docs.tweepy.org/en/latest/streaming_how_to.html
#
# Some other references:
# https://www.geeksforgeeks.org/twitter-sentiment-analysis-using-python/
# https://towardsdatascience.com/real-time-twitter-sentiment-analysis-for-brand-improvement-and-topic-tracking-chapter-1-3-e02f7652d8ff

# %%
#All the libraries used for data scraping

import pandas as pd
import tweepy
from textblob import TextBlob
import re
import credentials
import OpenSSL
import time

# %%
# Functions used to clean text

def deEmojify(text):
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None
    
def clean_tweet(tweet): 
    ''' 
    Use sumple regex statemnents to clean tweet text by removing links and special characters
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) \
                                |(\w+:\/\/\S+)", " ", tweet).split())

# %%
# Streaming With Tweepy 
# Create MyStreamListener to override tweepy.StreamListener to add logic to on_status

f = open("InstagramData.txt", "a")

count = 0

class MyStreamListener(tweepy.StreamListener):

    # Extract info from tweets
    def on_status(self, status):
        if status.retweeted:
            # Avoid retweeted info, and only original tweets will 
            # be received
            return True
        # Extract attributes from each tweet
        id_str = status.id_str
        created_at = status.created_at
        text = deEmojify(status.text)    # Pre-processing the text  
        text = clean_tweet(text)
#         sentiment_analysis = TextBlob(text).sentiment # TextBlob object is like Python strings that learned how to do NLP, TextBlob().sentiment return the simple sentiment analysis
#         polarity = sentiment_analysis.polarity
#         subjectivity = sentiment_analysis.subjectivity

        user_created_at = status.user.created_at
        user_location = status.user.location

        user_followers_count =status.user.followers_count
        user_friends_count =status.user.friends_count

        longitude = None
        latitude = None
        if status.coordinates:
            longitude = status.coordinates['coordinates'][0]
            latitude = status.coordinates['coordinates'][1]

        retweet_count = status.retweet_count
        favorite_count = status.favorite_count
        # Quick check contents in tweets
        delimiter = '\t'
        text = text.replace(delimiter, ' ').replace('\n', ' ')
        fields = [id_str, created_at, text, user_created_at, user_location, user_followers_count,
                                                                user_friends_count, longitude, latitude, retweet_count, favorite_count]
        
        f.write(delimiter.join(map(str, fields)) + '\n')
        f.flush()
        global count
        if count % 50 == 0:
            print('processed %s messages' % count)
        count += 1

        
    def on_error(self, status_code):
        '''
        Since Twitter API has rate limits, 
        stop srcraping data as it exceed to the thresold.
        '''
        if status_code == 420:
            # return False to disconnect the stream
            return False

# %%
# Import api/access_token keys from credentials.py

auth  = tweepy.OAuthHandler(credentials.API_KEY,
                            credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOKEN,
                      credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
# However, this part won't be reached as the stream listener won't stop automatically. 
# Press STOP button to finish the process.
while True:
    try:
        myStreamListener = MyStreamListener()
        myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
        TRACK_WORDS = ['instagram']
        myStream.filter(languages=["en"], track = TRACK_WORDS)
    except Exception as e:
        print(e)
        time.sleep(30)
# Out:
# processed 0 messages
# processed 50 messages
# processed 100 messages
# processed 150 messages
# processed 200 messages
# processed 250 messages
# processed 300 messages
# processed 350 messages
# processed 400 messages
# processed 450 messages
# processed 500 messages
# processed 550 messages
# processed 600 messages
# processed 650 messages
# processed 700 messages
# processed 750 messages
# processed 800 messages
# processed 850 messages
# processed 900 messages
# processed 950 messages
# processed 1000 messages
# processed 1050 messages
# processed 1100 messages
# processed 1150 messages
# processed 1200 messages
# processed 1250 messages
# processed 1300 messages
# processed 1350 messages
# processed 1400 messages
# processed 1450 messages
# processed 1500 messages
# processed 1550 messages
# processed 1600 messages
# processed 1650 messages
# processed 1700 messages
# processed 1750 messages
# processed 1800 messages
# processed 1850 messages
# processed 1900 messages
# ...
